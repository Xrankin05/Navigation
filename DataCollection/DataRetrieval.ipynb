# %% [markdown]
# This code is for data collecting purposes. Collects the number of houses, restaurants, hospitals, etc. Still under development.

# %%
# %pip install osmnx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx

location = "Manhattan, New York, United States"
graph = osmnx.graph_from_place(location)

# %%
nodes, edges = osmnx.graph_to_gdfs(graph)

# %%
nodes.head()
# Out:
#                   y          x  street_count          highway  ref railway  \
# osmid
# 30807314  40.790720 -73.963576             4              NaN  NaN     NaN
# 30978747  40.774267 -73.973425             4              NaN  NaN     NaN
# 30978752  40.774769 -73.974393             4              NaN  NaN     NaN
# 42421728  40.798048 -73.960044             3  traffic_signals  NaN     NaN
# 42421731  40.798654 -73.961474             4  traffic_signals  NaN     NaN
#
#                             geometry
# osmid
# 30807314  POINT (-73.96358 40.79072)
# 30978747  POINT (-73.97342 40.77427)
# 30978752  POINT (-73.97439 40.77477)
# 42421728  POINT (-73.96004 40.79805)
# 42421731  POINT (-73.96147 40.79865)

# %%
import osmnx
import matplotlib as pyplot

bbox = -73.93361, 40.80333, -73.95194, 40.81083

G = osmnx.graph.graph_from_bbox(bbox, network_type="all")
osmnx.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
buildings = osmnx.features_from_bbox(bbox,{"building": True})
len(buildings)
# Out:
# 1861

# %%
hospitals = osmnx.features_from_bbox(bbox, {"amenity": "hospital"})
len(hospitals)
# Out:
# 1

# %%
cafe = osmnx.features_from_bbox(bbox, {"amenity" : "cafe"})
len(cafe)
# Out:
# 5

# %%
bakery = osmnx.features_from_bbox(bbox, {"shop" : "bakery"})
len(bakery)
# Out:
# 1

# %%
supermarket = osmnx.features_from_bbox(bbox, {"shop" : "supermarket"})
len(supermarket)
# Out:
# 5

# %%
restaurant = osmnx.features_from_bbox(bbox, {"amenity" : "restaurant"})
len(restaurant)
# Out:
# 26

# %%
fast_food = osmnx.features_from_bbox(bbox, {"amenity" : "fast_food"})
len(fast_food)
# Out:
# 22

# %%
library = osmnx.features_from_bbox(bbox, {"amenity" : "library"})
len(library )
# Out:
# 1

# %%
school = osmnx.features_from_bbox(bbox, {"amenity" : "school"})
len(school)
# Out:
# 15

# %%
school = osmnx.features_from_bbox(bbox, {"building" : "school"})
len(school)
# Out:
# 5

# %%
apartment = osmnx.features_from_bbox(bbox, {"building" : "apartments"})
len(apartment)
# Out:
# 8

# %%
office = osmnx.features_from_bbox(bbox, {"office" : True})
len(office)
# Out:
# 10

# %%
clothing = osmnx.features_from_bbox(bbox, {"shop" : "clothes"})
len(clothing)
# Out:
# 11

# %%
department = osmnx.features_from_bbox(bbox, {"shop" : "department_store"})
len(department)
# Out:
# 2
